# %%
! python.exe -m pip install --upgrade pip
! pip install pandas
! pip install numpy
! pip install openpyxl
! pip install seaborn

# %%
import pandas as pd, numpy as np
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
print("\n*****Required libraries imported*****")
# Out:
# *****Required libraries imported*****

# %% [markdown]
# # Mention project raw data filename below

# %%
file_Name = 'cases_report_Microsoft Via Give Foundation_(All States)_2024-01-22.csv'

# %%
def csvORexcel():
    try:
        path = "C:\\Python\\read\\"+file_Name
        if file_Name.split('.')[-1].startswith('c'):
            df = pd.read_csv(path)
            return df
        elif file_Name.split('.')[-1].startswith('x'):
            df = pd.read_excel(path)
            return df
    except FileNotFoundError:
        print("The file name {0} has not found".format(path))

fn = file_Name

# %%
data0 = csvORexcel()
data0.head()
# Out:
#     Case Id    Createdon                                      Scheme/Doc  \
# 0  EP0282YR  07-Jun-2023                          E-Shram Card (Central)
# 1  EP0282Z8  07-Jun-2023                          E-Shram Card (Central)
# 2  EP02831X  07-Jun-2023  Indira Gandhi National Widow Pension Scheme_UP
# 3  EP028328  07-Jun-2023                          E-Shram Card (Central)
# 4  EP02832W  07-Jun-2023                          E-Shram Card (Central)
#
#   Scheme/Doc GUID                    Status Docket Submitted Date  \
# 0        SH0009HD  Scheme/Document received           13-Jun-2023
# 1        SH0009HD  Scheme/Document received           13-Jun-2023
# 2        SH0000LL             Data complete                   NaN
# 3        SH0009HD  Scheme/Document received           13-Jun-2023
# 4        SH0009HD  Scheme/Document received           13-Jun-2023
#
#   Benefit received Date HD Suspected Cases  \
# 0           13-Jun-2023      Not Suspected
# 1           13-Jun-2023      Not Suspected
# 2                   NaN      Not Suspected
# 3           13-Jun-2023      Not Suspected
# 4           13-Jun-2023      Not Suspected
#
#                       Case Organization        Case District Citizen GUID  \
# 0  UP - Microsoft (Via Give Foundation)  Gautam Buddha Nagar     PN02ETYB
# 1  UP - Microsoft (Via Give Foundation)  Gautam Buddha Nagar     PN02ETYU
# 2  UP - Microsoft (Via Give Foundation)  Gautam Buddha Nagar     PN02EU1D
# 3  UP - Microsoft (Via Give Foundation)  Gautam Buddha Nagar     PN02EU1L
# 4  UP - Microsoft (Via Give Foundation)  Gautam Buddha Nagar     PN02EU28
#
#             Citizen Name Gender        Mobile   Age Family GUID Family Name  \
# 0          Gauri Shankar      M  9.582183e+09  53.0    PG026NY9     Shankar
# 1  Bisamillah Bisamillah      M  9.953268e+09  60.0    PG026NYS  Bisamillah
# 2          Anokhi Anokhi      F  7.982190e+09  75.0    PG026O15      Anokhi
# 3            Afroj Afroj      M  9.871585e+09  53.0    PG026O1F       Afroj
# 4            Pooja Yadav      F  9.871006e+09  21.0    PG026O20       Yadav
#
#          HD ID     HD Name     Opsco name
# 0  Mohit.Yogi1  Mohit Yogi  Rahul Rastogi
# 1  Mohit.Yogi1  Mohit Yogi  Rahul Rastogi
# 2  Mohit.Yogi1  Mohit Yogi  Rahul Rastogi
# 3  Mohit.Yogi1  Mohit Yogi  Rahul Rastogi
# 4  Mohit.Yogi1  Mohit Yogi  Rahul Rastogi

# %%
states = {'AP':'Andhra Pradesh',
'AR':'Arunachal Pradesh',
'AS':'Assam',
'BR':'Bihar',
'BH':'Bihar',
'CT':'Chhattisgarh',
'CG':'Chhattisgarh',
'GA':'Goa',
'GJ':'Gujarat',
'HR':'Haryana',
'HP':'Himachal Pradesh',
'JH':'Jharkhand',
'KA':'Karnataka',
'KL':'Kerala',
'MP':'Madhya Pradesh',
'MH':'Maharashtra',
'MN':'Manipur',
'ML':'Meghalaya',
'MZ':'Mizoram',
'NL':'Nagaland',
'OR':'Odisha',
'PB':'Punjab',
'RJ':'Rajasthan',
'SK':'Sikkim',
'TN':'Tamil Nadu',
'TG':'Telangana',
'TR':'Tripura',
'UP':'Uttar Pradesh',
'UT':'Uttarakhand',
'WB':'West Bengal'}

# %% [markdown]
# # Data Cleaning

# %%
# Remove last row.
data0.drop(index = data0[data0.Createdon.isna()].index, inplace=True)

# Replace null values
data0['Scheme/Doc'].fillna('a', inplace=True)
data0['Citizen Name'].fillna('a', inplace=True)
data0['HD Name'].fillna('blank', inplace=True)
data0.Mobile.fillna(0, inplace=True)

# Deleting records with status "Case Aborted" and "Application rejected"
data0 = data0[(data0['Status'] != 'Case Aborted') & (data0['Status'] != 'Application rejected')]

# Changing status values and keeping only "Open/Submit/BR"
data0['Status'] = data0['Status'].apply(lambda x: 'Open' if x == 'Data complete' else 'Submitted' if x=='Docket submitted' else "Benefit Received" if x=='Scheme/Document received' else x)

# Changing Case Organization values from state initials to full state name.
data0['Case Organization'] = data0['Case Organization'].apply(lambda x: states[x[:2]])

# Renaming column "Case Organiisation" & "Case District" to "State" & "Disctrict"
data0.rename(columns={"Case Organization":"State","Case District":"District"}, inplace=True)

# Convert Mobile column from float to string for concatenation.
data0['Mobile'] = data0['Mobile'].apply(lambda x: str(x).strip())
#data0['Mobile'] = data0['Mobile'].astype('int64')
data0['Mobile'] = data0['Mobile'].astype('str')

# Change gender from initial letter to full form.
data0['Gender'] = data0['Gender'].apply(lambda x: 'Male' if x=='M' else 'Female' if x=='F' else 'Other' if x=='O' else x)

# Convert "Createdon", "Docket Submitted Date", "Benefit received Date" column data type to Datetime format
dt_col = ['Createdon', 'Docket Submitted Date', 'Benefit received Date', 'DOB']

for col in dt_col:
    try:
        data0[col] = pd.to_datetime(data0[col], format='mixed', errors='ignore')
    except KeyError:
        continue

data0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31511 entries, 0 to 32018
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Case Id                31511 non-null  object
#  1   Createdon              31511 non-null  datetime64[ns]
#  2   Scheme/Doc             31511 non-null  object
#  3   Scheme/Doc GUID        31511 non-null  object
#  4   Status                 31511 non-null  object
#  5   Docket Submitted Date  29732 non-null  datetime64[ns]
#  6   Benefit received Date  28426 non-null  datetime64[ns]
#  7   HD Suspected Cases     31511 non-null  object
#  8   State                  31511 non-null  object
#  9   District               31511 non-null  object
#  10  Citizen GUID           31511 non-null  object
#  11  Citizen Name           31511 non-null  object
#  12  Gender                 31511 non-null  object
#  13  Mobile                 31511 non-null  object
#  14  Age                    31511 non-null  float64
#  15  Family GUID            31511 non-null  object
#  16  Family Name            31510 non-null  object
#  17  HD ID                  31511 non-null  object
#  18  HD Name                31511 non-null  object
#  19  Opsco name             31511 non-null  object
# dtypes: datetime64[ns](3), float64(1), object(16)
# memory usage: 5.0+ MB

# %% [markdown]
# # Translate local language district name to English

# %%
# Renaming Case District name from local language to english

data0['District'] = data0['District'].apply(lambda x: "Dohad" if x=="દોહદ" else "Haridwar" if x=="हरिद्वार" else "UDHAM SINGH NAGAR".title() if (x=="उदम सिंह नगर" or x=="Udam Singh Nagar")
                             else "Sitamarhi" if x=="सीतामढ़ी" else "Mahasamund" if (x=="महासमुंद" or x=="Mahasamand") else "Rajgarh" if x=="राजगढ़" else "Muzaffarpur" if x=="मुजफ्फरपुर"
                             else "Nawada" if x=="नवादा" else "Balrampur" if x=="बलरामपुर" else "DAMOH".title() if x=="दमोह" else "Shravasti" if x=="श्रावस्ती"
                             else "NARMADA".title() if x=="નર્મદા" else "Chhatarpur" if (x=="छतरपुर" or x=="Chhattarpur") else 'East Singhbum' if x=='ईस्ट सिंघबम' else 'Chhindwara' if x=='छिंदवारा' 
                             else 'Jalna' if x=='जालना' else 'Dhule' if x=='धुळे' else "Dhanbad" if x=="धनबाद" else 'Banas Kantha' if x=='બનાસ કાંઠા' else x.title())

# Renaming column "Case Organiisation" & "Case District" to "State" & "Disctrict"
data0.rename(columns={"Case Organization":"State","Case District":"District"}, inplace=True)

data0['District'].value_counts()
# Out:
# District
# Gautam Buddha Nagar    31511
# Name: count, dtype: int64

# %% [markdown]
# # DFL Schemes
#
# - SH0009SW = Digital productivity Service_ Basic
# - SH000BM6 = Digital productivity Service_Basic
# - SH000AG6 = Digital Productivity Services_Advanced
# - SH000A32 = Long Training on Digital & Financial Inclusion_Private
# - SH0009SW = Short Training on Digital & Financial Inclusion_Private
# - SH000AG6 = Digital Productivity Services and and employability training_Advanced

# %% [markdown]
# # Removing DFL data

# %%
df = data0.copy()
dfl = data0[(data0['Scheme/Doc GUID'] == 'SH0009SW') | (data0['Scheme/Doc GUID'] == 'SH000AG6') | (data0['Scheme/Doc GUID'] == 'SH000A32') | (data0['Scheme/Doc GUID']=='SH0009SW') | (data0['Scheme/Doc GUID']=='SH000AG6') | (data0['Scheme/Doc GUID']=='SH000BM6')]
data0 = data0[(data0['Scheme/Doc GUID'] != 'SH0009SW') & (data0['Scheme/Doc GUID'] != 'SH000AG6') & (data0['Scheme/Doc GUID'] != 'SH000A32') & (data0['Scheme/Doc GUID']!='SH0009SW') & (data0['Scheme/Doc GUID']!='SH000AG6') & (data0['Scheme/Doc GUID']!='SH000BM6')]
print("DFL Count={0}\nE-Gov Count={1}".format(len(dfl),len(data0)))
# Out:
# DFL Count=2744
# E-Gov Count=28767

# %%
data0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28767 entries, 0 to 31647
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Case Id                28767 non-null  object
#  1   Createdon              28767 non-null  datetime64[ns]
#  2   Scheme/Doc             28767 non-null  object
#  3   Scheme/Doc GUID        28767 non-null  object
#  4   Status                 28767 non-null  object
#  5   Docket Submitted Date  27015 non-null  datetime64[ns]
#  6   Benefit received Date  25709 non-null  datetime64[ns]
#  7   HD Suspected Cases     28767 non-null  object
#  8   State                  28767 non-null  object
#  9   District               28767 non-null  object
#  10  Citizen GUID           28767 non-null  object
#  11  Citizen Name           28767 non-null  object
#  12  Gender                 28767 non-null  object
#  13  Mobile                 28767 non-null  object
#  14  Age                    28767 non-null  float64
#  15  Family GUID            28767 non-null  object
#  16  Family Name            28767 non-null  object
#  17  HD ID                  28767 non-null  object
#  18  HD Name                28767 non-null  object
#  19  Opsco name             28767 non-null  object
# dtypes: datetime64[ns](3), float64(1), object(16)
# memory usage: 4.6+ MB

# %%
# Creating column with name 'duplicate' by concatenation
data0['duplicate'] = data0['Scheme/Doc'] + data0['Citizen Name'] + data0['Mobile'] # Concatenation
data0['duplicate'] = data0['duplicate'].apply(lambda x: x.lower()) # Converting duplicate column in lower case because python considers ASCII values of each character while checking for duplicates.
dfl['duplicate'] = dfl['Scheme/Doc'] + dfl['Citizen Name'] + dfl['Mobile']
dfl['duplicate'] = dfl['duplicate'].apply(lambda x: x.lower())
df['duplicate'] = df['Citizen Name'] + df['Mobile']
df['duplicate'] = df['duplicate'].apply(lambda x: x.lower())

data0.head()
# Out:
#     Case Id  Createdon                                      Scheme/Doc  \
# 0  EP0282YR 2023-06-07                          E-Shram Card (Central)
# 1  EP0282Z8 2023-06-07                          E-Shram Card (Central)
# 2  EP02831X 2023-06-07  Indira Gandhi National Widow Pension Scheme_UP
# 3  EP028328 2023-06-07                          E-Shram Card (Central)
# 4  EP02832W 2023-06-07                          E-Shram Card (Central)
#
#   Scheme/Doc GUID            Status Docket Submitted Date  \
# 0        SH0009HD  Benefit Received            2023-06-13
# 1        SH0009HD  Benefit Received            2023-06-13
# 2        SH0000LL              Open                   NaT
# 3        SH0009HD  Benefit Received            2023-06-13
# 4        SH0009HD  Benefit Received            2023-06-13
#
#   Benefit received Date HD Suspected Cases          State  \
# 0            2023-06-13      Not Suspected  Uttar Pradesh
# 1            2023-06-13      Not Suspected  Uttar Pradesh
# 2                   NaT      Not Suspected  Uttar Pradesh
# 3            2023-06-13      Not Suspected  Uttar Pradesh
# 4            2023-06-13      Not Suspected  Uttar Pradesh
#
#               District Citizen GUID           Citizen Name  Gender  \
# 0  Gautam Buddha Nagar     PN02ETYB          Gauri Shankar    Male
# 1  Gautam Buddha Nagar     PN02ETYU  Bisamillah Bisamillah    Male
# 2  Gautam Buddha Nagar     PN02EU1D          Anokhi Anokhi  Female
# 3  Gautam Buddha Nagar     PN02EU1L            Afroj Afroj    Male
# 4  Gautam Buddha Nagar     PN02EU28            Pooja Yadav  Female
#
#          Mobile   Age Family GUID Family Name        HD ID     HD Name  \
# 0  9582182609.0  53.0    PG026NY9     Shankar  Mohit.Yogi1  Mohit Yogi
# 1  9953267914.0  60.0    PG026NYS  Bisamillah  Mohit.Yogi1  Mohit Yogi
# 2  7982189876.0  75.0    PG026O15      Anokhi  Mohit.Yogi1  Mohit Yogi
# 3  9871585042.0  53.0    PG026O1F       Afroj  Mohit.Yogi1  Mohit Yogi
# 4  9871005562.0  21.0    PG026O20       Yadav  Mohit.Yogi1  Mohit Yogi
#
#       Opsco name                                          duplicate
# 0  Rahul Rastogi    e-shram card (central)gauri shankar9582182609.0
# 1  Rahul Rastogi  e-shram card (central)bisamillah bisamillah995...
# 2  Rahul Rastogi  indira gandhi national widow pension scheme_up...
# 3  Rahul Rastogi      e-shram card (central)afroj afroj9871585042.0
# 4  Rahul Rastogi      e-shram card (central)pooja yadav9871005562.0

# %% [markdown]
# # Duplicate Data

# %%
# Checking number of all duplicate records
duplicateData = data0[data0.duplicated(['duplicate'],keep=False)].sort_values('duplicate')
dflDuplicates = dfl[dfl.duplicated(['duplicate'],keep=False)].sort_values('duplicate')
duplicateData = pd.concat([duplicateData,dflDuplicates], ignore_index=True)
duplicateData.reset_index(inplace=True, drop = True)

try:
    duplicateData.drop(index=duplicateData.index[-1], inplace=True)
except IndexError:
    print(duplicateData.shape)

duplicateData.shape
# Out:
# (554, 21)

# %% [markdown]
# # Unique Data

# %%
# Keeping uniques excluding duplicates
unique_data = data0.drop(index = data0[data0.duplicated(['duplicate'], keep='last')].index)
unique_data.reset_index(inplace=True, drop = True)
try:
    unique_data.drop(index=unique_data.index[-1], inplace=True)
except IndexError:
    print(unique_data.shape)

unique_data.shape
# Out:
# (28533, 21)

# %%
# Exporting data of all duplicate records to Excel file.
duplicateData.to_excel('C:\\Python\\export\\'+fn.split('.')[0]+'_duplicate.xlsx', index=False)
print('Export to Excel Success! Total {0} duplicate records exported.'.format(duplicateData.shape[0]))

#df.to_excel('C:\\Python\\export\\'+fn.split('.')[0]+'_cleaned.xlsx', index=False)
# Out:
# Export to Excel Success! Total 554 duplicate records exported.

# %%
# Exporting data of all duplicate records to Excel file.
with pd.ExcelWriter('C:\\Python\\export\\'+fn.split('.')[0]+'_uniques.xlsx') as writer:
    unique_data.to_excel(writer, sheet_name='Schemes data', index=False)
    if dfl.shape[0]<1:
        dfl.to_excel(writer, sheet_name='DFL data', index=False)
        
print('Export to Excel Success! Total {0} duplicate records exported.'.format(unique_data.shape[0]))
