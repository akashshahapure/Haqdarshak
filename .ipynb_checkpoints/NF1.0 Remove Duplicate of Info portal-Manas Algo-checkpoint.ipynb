# %%
! python.exe -m pip install --upgrade pip
! pip install pandas
! pip install numpy
! pip install openpyxl
import pandas as pd, numpy as np
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
print("\n*****Required libraries imported*****")
# Out:
# Requirement already satisfied: pip in c:\program files\python311\lib\site-packages (23.3.2)
# Requirement already satisfied: pandas in c:\users\akash\appdata\roaming\python\python311\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\program files\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\akash\appdata\roaming\python\python311\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\akash\appdata\roaming\python\python311\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\akash\appdata\roaming\python\python311\site-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in c:\program files\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\akash\appdata\roaming\python\python311\site-packages (1.25.2)
# Requirement already satisfied: openpyxl in c:\program files\python311\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\program files\python311\lib\site-packages (from openpyxl) (1.1.0)
#
# *****Required libraries imported*****

# %% [markdown]
# # Mention project raw data filename below

# %%
file_Name = 'cases_report_Nasscom1.0_All_(All States)_2023-12-22.csv'

# %%
def csvORexcel():
    try:
        path = "C:\\Python\\read\\"+file_Name
        if file_Name.split('.')[-1].startswith('c'):
            df = pd.read_csv(path)
            return df
        elif file_Name.split('.')[-1].startswith('x'):
            df = pd.read_excel(path)
            return df
    except FileNotFoundError:
        print("The file name {0} has not found".format(path))

fn = file_Name

# %%
data0 = csvORexcel()
data0.head()
# Out:
#     Case Id    Createdon                                         Scheme/Doc  \
# 0  EP01SUJR  28-Feb-2023                          Digital Health ID card_MP
# 1  EP01SVRD  28-Feb-2023                          Digital Health ID card_MP
# 2  EP01ZSA8  28-Mar-2023  Pradhan Mantri Jan Arogya Yojana (Ayushman Bha...
# 3  EP01ZSED  28-Mar-2023                       MP-Aadhar seeding to Samagra
# 4  EP0203IG  29-Mar-2023                                    E-Shram Card_MP
#
#   Scheme/Doc GUID                    Status Docket Submitted Date  \
# 0        SH0009I2  Scheme/Document received           21-Oct-2023
# 1        SH0009I2             Data complete                   NaN
# 2        SH0005P9  Scheme/Document received           21-Oct-2023
# 3        DC00097P             Data complete                   NaN
# 4        SH0009HI             Data complete                   NaN
#
#   Benefit received Date HD Suspected Cases        Case Organization  \
# 0           21-Oct-2023      Not Suspected  MP - Nasscom Foundation
# 1                   NaN      Not Suspected  MP - Nasscom Foundation
# 2           21-Oct-2023      Not Suspected  MP - Nasscom Foundation
# 3                   NaN      Not Suspected  MP - Nasscom Foundation
# 4                   NaN      Not Suspected  MP - Nasscom Foundation
#
#   Case District Citizen GUID          Citizen Name  Createdon.1          DOB  \
# 0         Damoh     PN01ZCK0        Parasmani Sahu  27-Feb-2023  01-Jan-1997
# 1         Damoh     PN01YXCW          Abhishek Rai  24-Feb-2023  14-Oct-1999
# 2         Damoh     PN026FQH  Naresh Kumar Ahirwar  28-Mar-2023  10-Jul-1999
# 3         Damoh     PN026FQH  Naresh Kumar Ahirwar  28-Mar-2023  10-Jul-1999
# 4         Damoh     PN01ZCK0        Parasmani Sahu  27-Feb-2023  01-Jan-1997
#
#   Gender      Mobile   Age   Citizen State Family GUID Family Name  \
# 0      M  9630483273  26.0  Madhya Pradesh    PG01S0GV        Sahu
# 1      M  8120331866  24.0  Madhya Pradesh    PG01RM4E         Rai
# 2      M  9625601462  24.0  Madhya Pradesh    PG01YRH3     Ahirwar
# 3      M  9625601462  24.0  Madhya Pradesh    PG01YRH3     Ahirwar
# 4      M  9630483273  26.0  Madhya Pradesh    PG01S0GV        Sahu
#
#          HD ID         HD Name      Opsco name
# 0  parash.sahu  Parasmani Sahu  Parasmani Sahu
# 1  parash.sahu  Parasmani Sahu  Parasmani Sahu
# 2  parash.sahu  Parasmani Sahu  Parasmani Sahu
# 3  parash.sahu  Parasmani Sahu  Parasmani Sahu
# 4  parash.sahu  Parasmani Sahu  Parasmani Sahu

# %% [markdown]
# # DFL Schemes
#
# - SH0009SW = Digital productivity Service_ Basic
# - SH000BM6 = Digital productivity Service_Basic
# - SH000AG6 = Digital Productivity Services_Advanced
# - SH000A32 = Long Training on Digital & Financial Inclusion_Private
# - SH0009SW = Short Training on Digital & Financial Inclusion_Private
# - SH000AG6 = Digital Productivity Services and and employability training_Advanced

# %% [markdown]
# # Removing DFL data

# %%
# Changing Case Organization values and keeping only state initials
data0['Case Organization'] = data0['Case Organization'].apply(lambda x: x.split(' ')[0])

dfl = data0[(data0['Scheme/Doc GUID'] == 'SH0009SW') | (data0['Scheme/Doc GUID'] == 'SH000AG6') | (data0['Scheme/Doc GUID'] == 'SH000A32') | (data0['Scheme/Doc GUID']=='SH0009SW') | (data0['Scheme/Doc GUID']=='SH000AG6') | (data0['Scheme/Doc GUID']=='SH000BM6')]
data0 = data0[(data0['Scheme/Doc GUID'] != 'SH0009SW') & (data0['Scheme/Doc GUID'] != 'SH000AG6') & (data0['Scheme/Doc GUID'] != 'SH000A32') & (data0['Scheme/Doc GUID']!='SH0009SW') & (data0['Scheme/Doc GUID']!='SH000AG6') & (data0['Scheme/Doc GUID']!='SH000BM6')]
print("DFL Count={0}\nE-Gov Count={1}".format(len(dfl),len(data0)))
# Out:
# DFL Count=0
# E-Gov Count=394999

# %%
data0['Case Organization'].value_counts()
# Out:
# Case Organization
# BH    81299
# UT    60804
# GJ    55805
# UP    55292
# MP    41730
# CG    22979
# PB    20157
# HP    14556
# HR    12325
# OR    11658
# AS     7768
# JH     5782
# ML     4844
# Name: count, dtype: int64

# %%
data0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 410323 entries, 0 to 1107067
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Case Id                410323 non-null  object
#  1   Createdon              410322 non-null  object
#  2   Scheme/Doc             410322 non-null  object
#  3   Scheme/Doc GUID        410322 non-null  object
#  4   Status                 410322 non-null  object
#  5   Docket Submitted Date  368878 non-null  object
#  6   Benefit received Date  362610 non-null  object
#  7   HD Suspected Cases     410322 non-null  object
#  8   Case Organization      410322 non-null  object
#  9   Case District          410322 non-null  object
#  10  Citizen GUID           410322 non-null  object
#  11  Citizen Name           410322 non-null  object
#  12  Createdon.1            410322 non-null  object
#  13  DOB                    410322 non-null  object
#  14  Gender                 410322 non-null  object
#  15  Mobile                 410322 non-null  object
#  16  Age                    410322 non-null  float64
#  17  Citizen State          410322 non-null  object
#  18  Family GUID            410322 non-null  object
#  19  Family Name            410321 non-null  object
#  20  HD ID                  410312 non-null  object
#  21  HD Name                410312 non-null  object
#  22  Opsco name             410312 non-null  object
# dtypes: float64(1), object(22)
# memory usage: 75.1+ MB

# %%
# Deleting records with status "Case Aborted" and "Application rejected"
data0 = data0[(data0['Status'] != 'Case Aborted') & (data0['Status'] != 'Application rejected')]

# Changing status values and keeping only "Open/Submit/BR"
data0['Status'] = data0['Status'].apply(lambda x: 'Open' if x == 'Data complete' else 'Submitted' if x=='Docket submitted' else "Benefit Received" if x=='Scheme/Document received' else x)

data0.shape
# Out:
# (394999, 23)

# %%
# Replace null values
data0['Scheme/Doc'].fillna('a', inplace=True)
data0['Citizen Name'].fillna('a', inplace=True)
data0['HD Name'].fillna('blank', inplace=True)
data0.Mobile.fillna(0, inplace=True)

# Convert Mobile column from float to string for concatenation.
data0['Mobile'] = data0['Mobile'].astype('int64')
data0['Mobile'] = data0['Mobile'].astype('str')

# Convert "Createdon", "Docket Submitted Date", "Benefit received Date" column data type to Datetime format
data0['Createdon'] = pd.to_datetime(data0['Createdon'])
data0['Docket Submitted Date'] = pd.to_datetime(data0['Docket Submitted Date'])
data0['Benefit received Date'] = pd.to_datetime(data0['Benefit received Date'])

# Removing row with max no. of blank fields.
rowwise_blanks = pd.DataFrame(data0.isnull().sum(axis=1)).rename(columns={0:'Blanks'}).reset_index(drop=False)
if rowwise_blanks.max()['Blanks'] > 10:
    data0.drop(index=rowwise_blanks.max()['index'],inplace=True)

data0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 394999 entries, 0 to 1107066
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Case Id                394999 non-null  object
#  1   Createdon              394999 non-null  datetime64[ns]
#  2   Scheme/Doc             394999 non-null  object
#  3   Scheme/Doc GUID        394999 non-null  object
#  4   Status                 394999 non-null  object
#  5   Docket Submitted Date  362943 non-null  datetime64[ns]
#  6   Benefit received Date  357469 non-null  datetime64[ns]
#  7   HD Suspected Cases     394999 non-null  object
#  8   Case Organization      394999 non-null  object
#  9   Case District          394999 non-null  object
#  10  Citizen GUID           394999 non-null  object
#  11  Citizen Name           394999 non-null  object
#  12  Createdon.1            394999 non-null  object
#  13  DOB                    394999 non-null  object
#  14  Gender                 394999 non-null  object
#  15  Mobile                 394999 non-null  object
#  16  Age                    394999 non-null  float64
#  17  Citizen State          394999 non-null  object
#  18  Family GUID            394999 non-null  object
#  19  Family Name            394998 non-null  object
#  20  HD ID                  394990 non-null  object
#  21  HD Name                394999 non-null  object
#  22  Opsco name             394990 non-null  object
# dtypes: datetime64[ns](3), float64(1), object(19)
# memory usage: 72.3+ MB

# %%
# Renaming Case District name from local language to english

data0['District'] = data0['District'].apply(lambda x: "Dohad" if x=="દોહદ" else "Haridwar" if x=="हरिद्वार" else "UDHAM SINGH NAGAR".title() if (x=="उदम सिंह नगर" or x=="Udam Singh Nagar")
                             else "Sitamarhi" if x=="सीतामढ़ी" else "Mahasamund" if (x=="महासमुंद" or x=="Mahasamand") else "Rajgarh" if x=="राजगढ़" else "Muzaffarpur" if x=="मुजफ्फरपुर"
                             else "Nawada" if x=="नवादा" else "Balrampur" if x=="बलरामपुर" else "DAMOH".title() if x=="दमोह" else "Shravasti" if x=="श्रावस्ती"
                             else "NARMADA".title() if x=="નર્મદા" else "Chhatarpur" if (x=="छतरपुर" or x=="Chhattarpur") else 'East Singhbum' if x=='ईस्ट सिंघबम' else 'Chhindwara' if x=='छिंदवारा' 
                             else 'Jalna' if x=='जालना' else 'Dhule' if x=='धुळे' else "Dhanbad" if x=="धनबाद" else x.title())

# Renaming column "Case Organiisation" & "Case District" to "State" & "Disctrict"
data0.rename(columns={"Case Organization":"State","Case District":"District"}, inplace=True)

data0['District'].value_counts()
# Out:
# Case District
# Haridwar            34830
# Dohad               32743
# Udam Singh Nagar    25974
# Narmada             23020
# Mahasamund          22978
# Sitamarhi           20209
# Muzaffarpur         20192
# Moga                20067
# Rajgarh             19191
# Aurangabad          16987
# Damoh               16930
# Shravasti           14916
# Chamba              14556
# Bahraich            13228
# Nawada              13208
# Nuh                 12309
# Gajapati            11658
# Fatehpur            11364
# Gaya                10703
# Balrampur            8929
# Chitrakoot           6855
# Godda                5782
# Chhatarpur           5609
# Ri Bhoi              4844
# Hailakandi           3910
# Udalguri             2774
# Baksa                1084
# Ferozepur              90
# Dahod                  42
# Faridabad              16
# Korba                   1
# Name: count, dtype: int64

# %%
# Creating column with name 'duplicate' by concatenation
data0['duplicate'] = data0['Scheme/Doc'] + data0['Citizen Name'] + data0['Mobile'] # Concatenation
data0['duplicate'] = data0['duplicate'].apply(lambda x: x.lower()) # Converting duplicate column in lower case because python considers ASCII values of each character while checking for duplicates.
data0.head()
# Out:
#     Case Id  Createdon                                         Scheme/Doc  \
# 0  EP01SUJR 2023-02-28                          Digital Health ID card_MP
# 1  EP01SVRD 2023-02-28                          Digital Health ID card_MP
# 2  EP01ZSA8 2023-03-28  Pradhan Mantri Jan Arogya Yojana (Ayushman Bha...
# 3  EP01ZSED 2023-03-28                       MP-Aadhar seeding to Samagra
# 4  EP0203IG 2023-03-29                                    E-Shram Card_MP
#
#   Scheme/Doc GUID            Status Docket Submitted Date  \
# 0        SH0009I2  Benefit Received            2023-10-21
# 1        SH0009I2              Open                   NaT
# 2        SH0005P9  Benefit Received            2023-10-21
# 3        DC00097P              Open                   NaT
# 4        SH0009HI              Open                   NaT
#
#   Benefit received Date HD Suspected Cases        Case Organization  \
# 0            2023-10-21      Not Suspected  MP - Nasscom Foundation
# 1                   NaT      Not Suspected  MP - Nasscom Foundation
# 2            2023-10-21      Not Suspected  MP - Nasscom Foundation
# 3                   NaT      Not Suspected  MP - Nasscom Foundation
# 4                   NaT      Not Suspected  MP - Nasscom Foundation
#
#   Case District Citizen GUID          Citizen Name  Createdon.1          DOB  \
# 0         Damoh     PN01ZCK0        Parasmani Sahu  27-Feb-2023  01-Jan-1997
# 1         Damoh     PN01YXCW          Abhishek Rai  24-Feb-2023  14-Oct-1999
# 2         Damoh     PN026FQH  Naresh Kumar Ahirwar  28-Mar-2023  10-Jul-1999
# 3         Damoh     PN026FQH  Naresh Kumar Ahirwar  28-Mar-2023  10-Jul-1999
# 4         Damoh     PN01ZCK0        Parasmani Sahu  27-Feb-2023  01-Jan-1997
#
#   Gender      Mobile   Age   Citizen State Family GUID Family Name  \
# 0      M  9630483273  26.0  Madhya Pradesh    PG01S0GV        Sahu
# 1      M  8120331866  24.0  Madhya Pradesh    PG01RM4E         Rai
# 2      M  9625601462  24.0  Madhya Pradesh    PG01YRH3     Ahirwar
# 3      M  9625601462  24.0  Madhya Pradesh    PG01YRH3     Ahirwar
# 4      M  9630483273  26.0  Madhya Pradesh    PG01S0GV        Sahu
#
#          HD ID         HD Name      Opsco name  \
# 0  parash.sahu  Parasmani Sahu  Parasmani Sahu
# 1  parash.sahu  Parasmani Sahu  Parasmani Sahu
# 2  parash.sahu  Parasmani Sahu  Parasmani Sahu
# 3  parash.sahu  Parasmani Sahu  Parasmani Sahu
# 4  parash.sahu  Parasmani Sahu  Parasmani Sahu
#
#                                            duplicate
# 0  digital health id card_mpparasmani sahu9630483273
# 1    digital health id card_mpabhishek rai8120331866
# 2  pradhan mantri jan arogya yojana (ayushman bha...
# 3  mp-aadhar seeding to samagranaresh kumar ahirw...
# 4            e-shram card_mpparasmani sahu9630483273

# %% [markdown]
# # Duplicate Data

# %%
# Checking number of all duplicate records
duplicateData = data0[data0.duplicated(['duplicate'],keep=False)].sort_values('duplicate')
duplicateData.reset_index(inplace=True, drop = True)
try:
    duplicateData.drop(index=duplicateData.index[-1], inplace=True)
except IndexError:
    print(duplicateData.shape)

duplicateData.shape
# Out:
# (6773, 24)

# %% [markdown]
# # Unique Data

# %%
# Keeping uniques excluding duplicates
unique_data = data0.drop(index = data0[data0.duplicated(['duplicate'], keep='last')].index)
unique_data.reset_index(inplace=True, drop = True)
try:
    unique_data.drop(index=unique_data.index[-1], inplace=True)
except IndexError:
    print(unique_data.shape)

unique_data.shape
# Out:
# (391321, 24)

# %%
# Exporting data of all duplicate records to Excel file.
duplicateData.to_excel('C:\\Python\\export\\'+fn.split('.')[0]+'_duplicate.xlsx', index=False)
print('Export to Excel Success! Total {0} duplicate records exported.'.format(duplicateData.shape[0]))
# Out:
# Export to Excel Success! Total 6773 duplicate records exported.

# %%
# Exporting data of all duplicate records to Excel file.
unique_data.to_excel('C:\\Python\\export\\'+fn.split('.')[0]+'_unique.xlsx', index=False)
print('Export to Excel Success! Total {0} duplicate records exported.'.format(unique_data.shape[0]))
# Out:
# Export to Excel Success! Total 391321 duplicate records exported.
